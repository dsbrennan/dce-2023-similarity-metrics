# %% [markdown]
# #### Copyright (c) 2023 Dan Brennan/University of Sheffield
#
# # Graph Comparisons using Maximum Common Subgraph/Jaccard Index
#
# This is code is for the generation of DCE 2023 JP. The paper details are:
#
# > Daniel S. Brennan, Timothy J. Rogers, Elizabeth J. Cross, Keith Worden.  * Calculating structural similarity in Population-based Structural Health Monitoring* Data Centric Engineering 2023.
#
# If you use this code, please cite the above paper.
#
# The goal of this notebook is to take the same datasets that have been used within the GMN papers previous (below) and compare the results and possible scenarios in which each algorithm has the most beneficial scenario for use.
#
# Introducing Graph Matching Networks and the Canonical Form for IE models:
#
# > Daniel S. Brennan, Timothy J. Rogers, Elizabeth J. Cross, Keith Worden.  * Calculating structure similarity via a Graph Neural Network in Population-based Structural Health Monitoring* ISMA 2022.
#
# Embedding element attributes as nodes:
#
# > Daniel S. Brennan, Timothy J. Rogers, Elizabeth J. Cross, Keith Worden.  * Calculating structure similarity via a Graph Neural Network in Population-based Structural Health Monitoring: Part II* IMAC-XLI.

# %% [markdown]
# ## Dependencies
# The code below relies upon some standard libraries as well as the backtracking algorithm implemented by Dr Julian Gosliga (https://github.com/jgosliga)
#
# To install the dependencies within a new virtual environment:
# ```
# pip install -r requirements.txt
# ```
#
# Note: the code was tested and built upon python 3.7.6

# %%
# Libraries for AttributedGraphDataset
import numpy as np
import os.path
import os
import json
import sys
import re
# Libraries for Graph Matching
import algorithm.backtracking as bt
# Libraries for Outputs
import matplotlib.pyplot as plt

# %% [markdown]
# ## Class to handle datasets
# For the GMN, a AttributedGraphDataset class was created to load our learning dataset (https://github.com/dsbrennan/ie-model-learning-data) into the GMN algorithm and package the IE models into graphs that the GMN code would understand.
#
# For the Graph Comparison, we have created a new AttributedGraphDataset class, but used the same method names where appropriate. The static factory method pattern of load_dataset is also used, taking a learning dataset and the canonical form datsset and returns an instantiated AttributedGraphDataset's for training, validation and test sets.

# %%
class AttributedGraphDataset:
    """Attributed Graph Dataset"""

    def __init__(self):
        """Constructor
        
        Initialises populations, graphs, labels and pairs storage lists
        """
        # Canonical Data Storage
        self._canonical_ids = []
        self._canonical_populations = []
        self._canonical_graphs = []
        # Graph Data Storage
        self._ids = []
        self._populations = []
        self._graphs = []
        # Pair Data Storage
        self._names = []
        self._pairs = []
    
    def add_canonical_reference_graphs(self, canonical_graph_data: list):
        """ Add Canonical Reference Graphs to Dataset

        'canoncial_graph_data': a list of canonical graph data
        """
        for i in range(0, len(canonical_graph_data)):
            # Add Data to storage
            self._canonical_ids.append(canonical_graph_data[i]["id"])
            self._canonical_populations.append(canonical_graph_data[i]["population"])
            self._canonical_graphs.append(canonical_graph_data[i]["graph"])

    def add_graph(self, id: str, population: str, graph: object):
        """Add Graph to Dataset

        'id': graph name
        'population': string of which population the corresponding graph belongs to
        'graph': a networkx graph representation of the IE model
        """
        # Generate Pairs & Append
        for i in range(0, len(self._canonical_graphs)):
            # Add G1 -> CG1 paid
            self._names.append((id, self._canonical_ids[i]))
            self._pairs.append((graph, self._canonical_graphs[i]))
        # Add Storage
        self._ids.append(id)
        self._populations.append(population)
        self._graphs.append(graph)

    @staticmethod
    def _generate_graph(elements: list, relationships: list):
        """Generate networkx graph representation of an IE model
        
        'elements': a list of IE model elements
        'relationships': a list of IE model relationships
        return: attributed graph with graph, attributes and count
        """
        # Add Nodes
        graph = {}
        attributes = {}
        for node in elements:
            graph[node["name"]] = []
            attributes[node["name"]] = node["contextual"]["type"] if "contextual" in node else "N/A"
        # Add Edges (Needs to be a N -> N loop to handle relationships with 2+ elements)
        for edge in relationships:
            for node_1 in edge["elements"]:
                for node_2 in edge["elements"]:
                    if node_1["name"] != node_2["name"]:
                        graph[node_1["name"]].append(node_2["name"])
        return {"graph": graph, "attributes": attributes, "count": {"elements": len(elements), "relationships": len(relationships)}}

    @staticmethod
    def load_dataset(folder: str, matching_dataset: str, canonical_dataset: str, population_regex: str, validation_percentage: float, test_size: int):
        """Load Dataset

        Generates Training and Validation AttributedGraphDataset's from dataset
        
        'folder': a string of the base directory to find the dataset within
        'matching_dataset': the name of the matching dataset to load
        'canonical_dataset': the name of the canonical dataset to load
        'population_regex': the regex needed to identify the population from the IE model name
        'validation_percentage': validation/training percentage
        'test_size': test size
        return: (Training Data Set, Validation Data Set, Test Data Set)
        """
        print(f"Loading Canonical Dataset: {canonical_dataset}")
        # Load Canonical dataset
        canonical_data = []
        if not os.path.isdir(os.path.join(folder, canonical_dataset)):
            raise ValueError(f"{os.path.join(folder, canonical_dataset)} does not exist")
            sys.exit()
        for item in os.listdir(os.path.join(folder, canonical_dataset)):
            if not os.path.isfile(os.path.join(folder, canonical_dataset, item)):
                continue
            elif item.rfind(".json") == (len(item) - 5):
                with open(os.path.join(folder, canonical_dataset, item)) as fs:
                    payload = json.loads(fs.read())
                    population = re.search(rf"{population_regex}", payload["name"])
                    graph = AttributedGraphDataset._generate_graph(payload["models"]["irreducibleElement"]["elements"], payload["models"]["irreducibleElement"]["relationships"])
                    canonical_data.append({"id": payload["name"], "population": population.group(), "graph": graph})
        print(f"Total number of Canonical datapoints: {len(canonical_data)}")
        print(f"Loading Matching Dataset: {matching_dataset}")
        # Load Matching Dataset
        if not os.path.isdir(os.path.join(folder, matching_dataset)):
            raise ValueError(f"{os.path.join(folder, matching_dataset)} does not exist")
            sys.exit()
        data = []
        for item in os.listdir(os.path.join(folder, matching_dataset)):
            if not os.path.isfile(os.path.join(folder, matching_dataset, item)):
                continue
            elif item.rfind(".json") == (len(item) - 5):
                with open(os.path.join(folder, matching_dataset, item)) as fs:
                    payload = json.loads(fs.read())
                    population = re.search(rf"{population_regex}", payload["name"])
                    graph = AttributedGraphDataset._generate_graph(payload["models"]["irreducibleElement"]["elements"], payload["models"]["irreducibleElement"]["relationships"])
                    data.append({"id": payload["name"], "population": population.group(), "graph": graph})
        print(f"Total number of Matching datapoints: {len(data)}")
        # Sort then Shuffle matching data for consistent dataset splits across notebooks
        data.sort(key=lambda item: item["id"])
        np.random.shuffle(data)
        # Calculate Split for Training, Validation & Test
        dataset_size = len(data)
        test_split = test_size
        validation_split = dataset_size - int(dataset_size * ((100.0 - validation_percentage) / 100.0))
        training_split = dataset_size - validation_split - test_split
        np.random.shuffle(canonical_data)#This must be done after the shuffle on the matching dataset to keep CF and none CF outputs the same
        # Create datasets
        training_set = AttributedGraphDataset()
        training_set.add_canonical_reference_graphs(canonical_data)
        training_set_metrics = {}
        for i in range(0, training_split):
            training_set.add_graph(data[i]["id"], data[i]["population"], data[i]["graph"])
            training_set_metrics[data[i]["population"]] = 1 if data[i]["population"] not in training_set_metrics else training_set_metrics[data[i]["population"]] + 1
        validation_set = AttributedGraphDataset()
        validation_set.add_canonical_reference_graphs(canonical_data)
        validation_set_metrics = {}
        for i in range(training_split, training_split + validation_split):
            validation_set.add_graph(data[i]["id"], data[i]["population"], data[i]["graph"])
            validation_set_metrics[data[i]["population"]] = 1 if data[i]["population"] not in validation_set_metrics else validation_set_metrics[data[i]["population"]] + 1
        test_set = AttributedGraphDataset()
        test_set.add_canonical_reference_graphs(canonical_data)
        test_set_metrics = {}
        for i in range(training_split + validation_split, training_split + validation_split + test_split):
            test_set.add_graph(data[i]["id"], data[i]["population"], data[i]["graph"])
            test_set_metrics[data[i]["population"]] = 1 if data[i]["population"] not in test_set_metrics else test_set_metrics[data[i]["population"]] + 1
        # Output Diagnostics
        print(f"Training Set Size: {len(training_set._pairs)} ({len(training_set._ids)} individual graphs)")
        print(*[f"\tPopulation: {metric} Count: {training_set_metrics[metric]}" for metric in training_set_metrics], sep="\r\n")
        print(f"Validation Set Size: {len(validation_set._pairs)} ({len(validation_set._ids)} individual graphs)")
        print(*[f"\tPopulation: {metric} Count: {validation_set_metrics[metric]}" for metric in validation_set_metrics], sep="\r\n")
        print(f"Test Set Size: {len(test_set._pairs)} ({len(test_set._ids)} individual graphs)")
        print(*[f"\tPopulation: {metric} Count: {test_set_metrics[metric]}" for metric in test_set_metrics], sep="\r\n")

        return training_set, validation_set, test_set

# %% [markdown]
# ## Load datasets
# Load the learning matching dataset and canonical form dataset.

# %%
# Set Seed for documenation
np.random.seed(7)
# Generate Training, Validation & Test datasets from matching and canoncial datasets
training_set, validation_set, test_set = AttributedGraphDataset.load_dataset(
    folder="/home/danbrennan/Code/ie-model-learning-data/data",
    matching_dataset="learning-slab-bridge-500-span-1-9-column-1-1-node-1-3",
    canonical_dataset="learning-slab-bridge-interim-canonical-form-span-1-9-column-1-1",
    population_regex="[0-9]+-span",
    validation_percentage=1.0,
    test_size=40
)
# Out:
# Loading Canonical Dataset: learning-slab-bridge-interim-canonical-form-span-1-9-column-1-1
# Total number of Canonical datapoints: 9
# Loading Matching Dataset: learning-slab-bridge-500-span-1-9-column-1-1-node-1-3
# Total number of Matching datapoints: 4500
# Training Set Size: 39735 (4415 individual graphs)
# 	Population: 1-span Count: 489
# 	Population: 7-span Count: 490
# 	Population: 4-span Count: 492
# 	Population: 3-span Count: 489
# 	Population: 9-span Count: 489
# 	Population: 5-span Count: 483
# 	Population: 6-span Count: 496
# 	Population: 8-span Count: 492
# 	Population: 2-span Count: 495
# Validation Set Size: 405 (45 individual graphs)
# 	Population: 3-span Count: 9
# 	Population: 4-span Count: 3
# 	Population: 7-span Count: 5
# 	Population: 9-span Count: 6
# 	Population: 5-span Count: 11
# 	Population: 1-span Count: 3
# 	Population: 8-span Count: 4
# 	Population: 2-span Count: 4
# Test Set Size: 360 (40 individual graphs)
# 	Population: 8-span Count: 4
# 	Population: 4-span Count: 5
# 	Population: 9-span Count: 5
# 	Population: 1-span Count: 8
# 	Population: 6-span Count: 4
# 	Population: 5-span Count: 6
# 	Population: 7-span Count: 5
# 	Population: 3-span Count: 2
# 	Population: 2-span Count: 1

# %% [markdown]
# ## Perform Graph Comparisons
# Iterate through the pairs of comparisons within the test dataset (the same which is used within the GMN) and perform the backtracking algorithm against the pair.
# Calculate the Jaccard Index for each pair and the maximum common subgraph

# %%
number_of_pairs = len(test_set._pairs)
paired_similarity_metrics = []
paired_maximum_common_subgraphs = []
for index, (graph_1, graph_2) in enumerate(test_set._pairs):
    print(f"Matching Pair {index}/{number_of_pairs}: {test_set._names[index][0]} and {test_set._names[index][1]}")
    # Largest graph must be the first parameter
    diagnostic_filename = f"{index}-{test_set._names[index][0]}-{test_set._names[index][1]}.json"
    backtrack_results = bt.backtrack(graph_2, graph_1, filename=diagnostic_filename) if graph_1["count"]["elements"] < graph_2["count"]["elements"] else bt.backtrack(graph_1, graph_2, filename=diagnostic_filename)
    ## Maximum Common Subgraph
    maximum_common_subgraphs = []
    for result in backtrack_results:
        if len(maximum_common_subgraphs) == 0 or len(result) > len(maximum_common_subgraphs[0]):
            maximum_common_subgraphs = [result]
        elif len(result) == len(maximum_common_subgraphs[0]):
            maximum_common_subgraphs.append(result)
    paired_maximum_common_subgraphs.append(maximum_common_subgraphs)
    ## Jaccard Index
    jaccard_index = len(maximum_common_subgraphs[0]) / (graph_1["count"]["elements"] + graph_2["count"]["elements"] - len(maximum_common_subgraphs[0]))
    paired_similarity_metrics.append(jaccard_index)
# Out:
# Matching Pair 0/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 1/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 2/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 3/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 4/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 5/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 6/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 7/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 8/360: slab-bridge-384-8-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 9/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 10/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 11/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 12/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 13/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 14/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 15/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 16/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 17/360: slab-bridge-379-4-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 18/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 19/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 20/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 21/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 22/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 23/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 24/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 25/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 26/360: slab-bridge-175-9-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 27/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 28/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 29/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 30/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 31/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 32/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 33/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 34/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 35/360: slab-bridge-399-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 36/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 37/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 38/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 39/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 40/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 41/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 42/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 43/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 44/360: slab-bridge-344-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 45/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 46/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 47/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 48/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 49/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 50/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 51/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 52/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 53/360: slab-bridge-272-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 54/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 55/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 56/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 57/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 58/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 59/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 60/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 61/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 62/360: slab-bridge-124-6-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 63/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 64/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 65/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 66/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 67/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 68/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 69/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 70/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 71/360: slab-bridge-220-5-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 72/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 73/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 74/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 75/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 76/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 77/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 78/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 79/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 80/360: slab-bridge-215-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 81/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 82/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 83/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 84/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 85/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 86/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 87/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 88/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 89/360: slab-bridge-176-8-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 90/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 91/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 92/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 93/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 94/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 95/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 96/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 97/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 98/360: slab-bridge-13-7-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 99/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 100/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 101/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 102/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 103/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 104/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 105/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 106/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 107/360: slab-bridge-88-4-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 108/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 109/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 110/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 111/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 112/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 113/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 114/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 115/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 116/360: slab-bridge-52-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 117/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 118/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 119/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 120/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 121/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 122/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 123/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 124/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 125/360: slab-bridge-4-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 126/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 127/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 128/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 129/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 130/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 131/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 132/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 133/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 134/360: slab-bridge-77-5-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 135/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 136/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 137/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 138/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 139/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 140/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 141/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 142/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 143/360: slab-bridge-216-7-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 144/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 145/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 146/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 147/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 148/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 149/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 150/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 151/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 152/360: slab-bridge-489-9-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 153/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 154/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 155/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 156/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 157/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 158/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 159/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 160/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 161/360: slab-bridge-233-9-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 162/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 163/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 164/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 165/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 166/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 167/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 168/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 169/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 170/360: slab-bridge-477-5-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 171/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 172/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 173/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 174/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 175/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 176/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 177/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 178/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 179/360: slab-bridge-410-3-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 180/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 181/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 182/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 183/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 184/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 185/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 186/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 187/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 188/360: slab-bridge-450-7-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 189/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 190/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 191/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 192/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 193/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 194/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 195/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 196/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 197/360: slab-bridge-329-4-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 198/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 199/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 200/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 201/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 202/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 203/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 204/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 205/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 206/360: slab-bridge-387-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 207/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 208/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 209/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 210/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 211/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 212/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 213/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 214/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 215/360: slab-bridge-138-5-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 216/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 217/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 218/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 219/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 220/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 221/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 222/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 223/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 224/360: slab-bridge-244-8-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 225/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 226/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 227/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 228/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 229/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 230/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 231/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 232/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 233/360: slab-bridge-208-4-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 234/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 235/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 236/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 237/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 238/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 239/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 240/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 241/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 242/360: slab-bridge-422-9-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 243/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 244/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 245/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 246/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 247/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 248/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 249/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 250/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 251/360: slab-bridge-377-7-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 252/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 253/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 254/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 255/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 256/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 257/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 258/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 259/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 260/360: slab-bridge-95-8-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 261/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 262/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 263/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 264/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 265/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 266/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 267/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 268/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 269/360: slab-bridge-93-5-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 270/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 271/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 272/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 273/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 274/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 275/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 276/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 277/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 278/360: slab-bridge-465-3-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 279/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 280/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 281/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 282/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 283/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 284/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 285/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 286/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 287/360: slab-bridge-358-1-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 288/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 289/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 290/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 291/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 292/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 293/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 294/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 295/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 296/360: slab-bridge-424-9-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 297/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 298/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 299/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 300/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 301/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 302/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 303/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 304/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 305/360: slab-bridge-236-5-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 306/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 307/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 308/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 309/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 310/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 311/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 312/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 313/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 314/360: slab-bridge-191-2-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 315/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 316/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 317/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 318/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 319/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 320/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 321/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 322/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 323/360: slab-bridge-8-6-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 324/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 325/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 326/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 327/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 328/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 329/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 330/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 331/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 332/360: slab-bridge-354-4-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 333/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 334/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 335/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 336/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 337/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 338/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 339/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 340/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 341/360: slab-bridge-152-7-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 342/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 343/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 344/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 345/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 346/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 347/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 348/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 349/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 350/360: slab-bridge-220-6-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column
# Matching Pair 351/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-1-span-1-column
# Matching Pair 352/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-7-span-1-column
# Matching Pair 353/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-4-span-1-column
# Matching Pair 354/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-2-span-1-column
# Matching Pair 355/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-8-span-1-column
# Matching Pair 356/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-6-span-1-column
# Matching Pair 357/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-9-span-1-column
# Matching Pair 358/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-5-span-1-column
# Matching Pair 359/360: slab-bridge-76-6-span-1-columns and slab-bridge-interim-canonical-form-3-span-1-column

# %% [markdown]
# ## Outputs
# Create a sorted similarity matrix from the Jaccard index scores

# %%
# Order Bridge IDs
sorted_population_list = sorted(list(dict.fromkeys(test_set._populations)))
sorted_id_list = []
for population in sorted_population_list:
    id_list = []
    for i in range(0, len(test_set._populations)):
        if test_set._populations[i] != population:
            continue
        id_list.append(test_set._ids[i])
    sorted_id_list.extend(sorted(id_list))

# Order Canonical IDs
sorted_canonical_population_list = sorted(list(dict.fromkeys(test_set._canonical_populations)))
sorted_canonical_id_list = []
for population in sorted_canonical_population_list:
    canonical_id_list = []
    for i in range(0, len(test_set._canonical_populations)):
        if test_set._canonical_populations[i] != population:
            continue
        canonical_id_list.append(test_set._canonical_ids[i])
    sorted_canonical_id_list.extend(sorted(canonical_id_list))

# Similarity Matrix
id_similarity_matrix = np.zeros((len(sorted_id_list), len(sorted_canonical_id_list)))
for i in range(0, len(paired_similarity_metrics)):
    id_similarity_matrix[sorted_id_list.index(test_set._names[i][0])][sorted_canonical_id_list.index(test_set._names[i][1])] = paired_similarity_metrics[i]

# Generate Friendly Names
sorted_id_friendly_list = []
for i in range(0, len(sorted_id_list)):
    match = re.search(rf"[0-9]+-[0-9]+-span", sorted_id_list[i])
    parts = match.group().split("-")
    sorted_id_friendly_list.append("{0} (#{1})".format(parts[1], parts[0]))
sorted_canonical_id_friendly_list = []
for i in range(0, len(sorted_canonical_id_list)):
    match = re.search(rf"[0-9]+-span", sorted_canonical_id_list[i])
    sorted_canonical_id_friendly_list.append(match.group().replace("-span", ""))

# %% [markdown]
# Display a heatmap for all of the test set results

# %%
#Display Heat Map
fig, ax = plt.subplots(figsize=(0.3 * len(sorted_canonical_id_friendly_list), 0.277 * len(sorted_id_friendly_list)), dpi=300)
im = ax.imshow(id_similarity_matrix)

ax.set_xticks(np.arange(len(test_set._canonical_ids)), labels=sorted_canonical_id_friendly_list, fontsize="6")
ax.set_yticks(np.arange(len(test_set._ids)), labels=sorted_id_friendly_list, ha="left", va="center", position=(-0.18, 0), fontsize="6")

for i in range(len(sorted_id_list)):
    for j in range(len(sorted_canonical_id_list)):
        text = ax.text(j, i, "{:.3f}".format(id_similarity_matrix[i, j]), ha="center", va="center", color="w", fontsize="4")

# fig.colorbar(im)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Paper Outputs
# Create a reduced set of results of 1 structure per population for display within the paper

# %%
# Output Settings
desired_inputs_per_population = 3
desired_population_filter = [2, 6]

# Get the desired input
desired_inputs = {}
desired_populations = []
for i,input in enumerate(sorted_id_friendly_list):
    parts = input.split(" ")
    if int(parts[0]) < desired_population_filter[0] or int(parts[0]) > desired_population_filter[1]:
        continue
    if desired_populations.count(parts[0]) < desired_inputs_per_population:
        desired_inputs[input] = i
        desired_populations.append(parts[0])

#Get Matrix
desired_id_matrix = np.zeros((len(desired_inputs), len(sorted_canonical_id_list)))
for i, key in enumerate(desired_inputs):
    desired_id_matrix[i] = id_similarity_matrix[desired_inputs[key]]

#Generate Display Names
canonical_display_names = [f"{int(item) + 1}" for item in sorted_canonical_id_friendly_list]
desired_display_names = []
for key in desired_inputs:
    search = re.search("([0-9]) \(#([0-9]+)\)", key)
    desired_display_names.append(f"{int(search.groups()[0]) + 1} (#{search.groups()[0]}-{search.groups()[1]})")

#Display Heat Map
fig, ax = plt.subplots(figsize=(0.3 * len(sorted_canonical_id_friendly_list), 0.277 * len(desired_inputs)), dpi=300)
im = ax.imshow(desired_id_matrix)

ax.set_xticks(np.arange(len(test_set._canonical_ids)), labels=canonical_display_names, fontsize="6")
ax.set_yticks(np.arange(len(desired_inputs)), labels=desired_display_names, ha="left", va="center", position=(-0.22, 0), fontsize="6")

for i in range(len(desired_inputs)):
    for j in range(len(sorted_canonical_id_list)):
        text = ax.text(j, i, "{:.3f}".format(desired_id_matrix[i, j]), ha="center", va="center", color="w", fontsize="4")

# fig.colorbar(im)
fig.tight_layout()
plt.show()
